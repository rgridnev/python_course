# %% [markdown]
# # Pandas: домашняя работа
#
# ## Задание 1
#
# Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера. Определите какому фильму было выставлено больше всего оценок 5.0.

# %%
import pandas as pd

# %%
ratings = pd.read_csv('ml-latest-small/ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
filtered_ratings = ratings[ (ratings['rating']==5.0)]
fivecount = filtered_ratings.groupby('movieId').count()
fivecount.sort_values(by=['rating'], ascending=[False]).head(1)
# Out:
#          userId  rating  timestamp
# movieId
# 318         153     153        153

# %% [markdown]
# ## Задание 2
#
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
data = pd.read_csv('power.csv')
data.head()
# Out:
#    country  year  quantity  category
# 0  Austria  1996       5.0         1
# 1  Austria  1995      17.0         1
# 2  Belgium  2014       0.0         1
# 3  Belgium  2013       0.0         1
# 4  Belgium  2012      35.0         1

# %%
data[ data['country'].str.contains('lat', case=False) ]['country'].unique()

filtered_data =  data[ ((data['country'] == 'Latvia') | 
                        (data['country'] == 'Lithuania') |
                        (data['country'] == 'Estonia')) & 
                      ((data['year'] < 2010) &  (data['year'] > 2005)) &
                      ((data['category'] == 4) | 
                        (data['category'] == 12) |
                        (data['category'] == 21)) &
                      (data['quantity'] >= 0)
                     ]
sum = filtered_data['quantity'].sum()

sum
# Out:
# 164555.0

# %% [markdown]
# ## Задание 3
#
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.
# Примеры страниц (необязательно брать именно эти):
# https://fortrader.org/quotes
# https://www.finanz.ru/valyuty/v-realnom-vremeni

# %%
ins = pd.read_html('https://autoins.ru/osago/informatsiya-o-kompaniyakh/perechen-strakhovykh-kompaniy-chlenov-rsa/deystvitelnye-chleny-rsa/')

ins[0]
# Out:
#        0                                                  1   \
# 0   № п/п                                Полное наименование
# 1       1  Общество с ограниченной ответственностью "Абсо...
# 2       2  Общество с ограниченной ответственностью "Стра...
# 3       3            Акционерное общество "АльфаСтрахование"
# 4       4   Акционерное общество Страховая компания "Армеец"
# 5       5  Публичное акционерное общество "АСКО-СТРАХОВАНИЕ"
# 6       6  Акционерное общество "Страховая компания "Астр...
# 7       7     Акционерное общество Страховая компания "БАСК"
# 8       8  Акционерное общество "Боровицкое страховое общ...
# 9       9  Общество с ограниченной ответственностью Страх...
# 10     10               Страховое акционерное общество "ВСК"
# 11     11    Акционерное общество "Страховая компания ГАЙДЕ"
# 12     12  Общество с ограниченной ответственностью Страх...
# 13     13  Общество с ограниченной ответственностью Страх...
# ...
